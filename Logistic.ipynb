# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sd=pd.read_csv("carprices.csv")
sd
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
sd.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Mileage        20 non-null     int64
#  1   Age(yrs)       20 non-null     int64
#  2   Sell Price($)  20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes

# %%
sd.describe()
# Out:
#             Mileage   Age(yrs)  Sell Price($)
# count     20.000000  20.000000      20.000000
# mean   59736.500000   5.150000   25197.500000
# std    20595.441825   1.785173    7834.479713
# min    22500.000000   2.000000   12000.000000
# 25%    50500.000000   4.000000   19375.000000
# 50%    59000.000000   5.000000   26050.000000
# 75%    73750.000000   6.250000   31625.000000
# max    91000.000000   8.000000   40000.000000

# %%
sd.isnull().sum()
# Out:
# Mileage          0
# Age(yrs)         0
# Sell Price($)    0
# dtype: int64

# %%
sd.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
X=sd[["Mileage","Age(yrs)"]]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y=sd["Sell Price($)"]
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg=LogisticRegression(solver='saga',max_iter=1000)

# %%
reg.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='saga')

# %%
reg.predict([[57000,6]])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([19400], dtype=int64)

# %%
plt.scatter(x=sd["Mileage"],y=sd["Sell Price($)"])
plt.show()

# %%
plt.plot(sd["Mileage"])
plt.ylabel("Mileage")
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(X_train)
plt.show()

# %%
sns.pairplot(sd)
plt.show()

# %%
sns.barplot(x = sd['Mileage'], y =sd['Sell Price($)'])
sns.set(rc={"figure.figsize": (10, 10)}) 
plt.show()

# %%
sns.countplot(x=sd["Age(yrs)"])
sns.set(rc={"figure.figsize": (2, 5)}) 
plt.show()
